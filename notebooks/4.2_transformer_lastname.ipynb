# %%
import string

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim.adamw import AdamW

from tqdm import tqdm
tqdm.pandas()

import pandas as pd
import numpy as np

from fastprogress import master_bar, progress_bar

from sklearn.feature_extraction.text import CountVectorizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## load data

# %%
train_df = pd.read_csv("/content/drive/MyDrive/Colab/ethnicolor/data/fl_2022_LastName_train.csv.gz")
val_df = pd.read_csv("/content/drive/MyDrive/Colab/ethnicolor/data/fl_2022_LastName_val.csv.gz")
test_df = pd.read_csv("/content/drive/MyDrive/Colab/ethnicolor/data/fl_2022_LastName_test.csv.gz")

# %%
train_df.head()
# Out:
#            name_last  asian  hispanic  nh_black  nh_white     other  total_n  \
# 0  Neaman-Piotrowicz    0.0       0.0       0.0  1.000000  0.000000      1.0
# 1              Chaet    0.0       0.0       0.0  1.000000  0.000000     13.0
# 2        Veloz Perez    0.0       1.0       0.0  0.000000  0.000000      1.0
# 3            Spalter    0.0       0.0       0.0  0.928571  0.071429     42.0
# 4     Kearns-Edwards    0.0       0.0       0.0  1.000000  0.000000      1.0
#
#        race  race_code
# 0  nh_white          3
# 1  nh_white          3
# 2  hispanic          1
# 3  nh_white          3
# 4  nh_white          3

# %%
print(train_df.shape)
print(val_df.shape)
print(test_df.shape)
# Out:
# (845316, 9)
# (105664, 9)
# (105665, 9)

# %%
train_df.head()
# Out:
#            name_last  asian  hispanic  nh_black  nh_white     other  total_n  \
# 0  Neaman-Piotrowicz    0.0       0.0       0.0  1.000000  0.000000      1.0
# 1              Chaet    0.0       0.0       0.0  1.000000  0.000000     13.0
# 2        Veloz Perez    0.0       1.0       0.0  0.000000  0.000000      1.0
# 3            Spalter    0.0       0.0       0.0  0.928571  0.071429     42.0
# 4     Kearns-Edwards    0.0       0.0       0.0  1.000000  0.000000      1.0
#
#        race  race_code
# 0  nh_white          3
# 1  nh_white          3
# 2  hispanic          1
# 3  nh_white          3
# 4  nh_white          3

# %% [markdown]
# ## Creating Vocab

# %%
vectorizer = CountVectorizer(analyzer='char', lowercase=False)

# %%
vectorizer.fit_transform(train_df['name_last'])
# Out:
# <845316x55 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7105885 stored elements in Compressed Sparse Row format>

# %%
vocab = list(vectorizer.get_feature_names_out())

# %%
n_letters = len(vocab)

# %% [markdown]
# ## Creating Dataset

# %%
race_id_df = train_df[['race', 'race_code']].drop_duplicates().sort_values('race_code')
race_to_id = dict(race_id_df.values)
id_to_race = dict(race_id_df[['race_code', 'race']].values)
all_categories = list(id_to_race.values())
n_categories = len(all_categories)
seq_len = train_df['name_last'].str.len().max()

# %%
print(f"classes - {all_categories}")
print(f"no of classes - {n_categories}")
print(f"max seq len - {seq_len}")
# Out:
# classes - ['asian', 'hispanic', 'nh_black', 'nh_white', 'other']
# no of classes - 5
# max seq len - 30

# %%
# helper methods used for transform in dataset

all_letters = ''.join(vocab)
oob = n_letters + 1

def letterToIndex(letter):
    return all_letters.find(letter)

def lineToTensor(line):
    tensor = torch.ones(seq_len) * oob
    for li, letter in enumerate(line):
        tensor[li] = letterToIndex(letter)
    return tensor

# %%
lineToTensor('Jason')
# Out:
# tensor([12., 29., 47., 43., 42., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56.])

# %%
print(lineToTensor('Jason').size())
# Out:
# torch.Size([30])

# %%
# A custom Dataset class must implement three functions: __init__, __len__, and __getitem__

class EthniColorDataset(Dataset):
  def __init__(self, data_df, transform=None):
    self.df = data_df
    self.transform = transform

  def __len__(self):
    return len(self.df)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    name = self.df.iloc[idx, train_df.columns.get_loc('name_last')]
    if self.transform:
      name = self.transform(name)
    label = self.df.iloc[idx, train_df.columns.get_loc('race_code')]
    #target = getTarget(label)
    target = torch.tensor(label, dtype=torch.int64)
    return name, target

# %%
train_dataset = EthniColorDataset(train_df, lineToTensor)
val_dataset = EthniColorDataset(val_df, lineToTensor)
test_dataset = EthniColorDataset(test_df, lineToTensor)

# %%
for i in range(3):
  name, label = train_dataset[i]
  print(i, name, label)
# Out:
# 0 tensor([16., 33., 29., 41., 29., 42.,  2., 18., 37., 43., 48., 46., 43., 51.,
#         37., 31., 54., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56.]) tensor(3)
# 1 tensor([ 5., 36., 29., 33., 48., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56.]) tensor(3)
# 2 tensor([24., 33., 40., 43., 54.,  0., 18., 33., 46., 33., 54., 56., 56., 56.,
#         56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56., 56.,
#         56., 56.]) tensor(1)

# %%
import os
# The Dataset retrieves our dataset’s features and labels one sample at a time.
# While training a model, we typically want to pass samples in “minibatches”,
# reshuffle the data at every epoch to reduce model overfitting, and
# use Python’s multiprocessing to speed up data retrieval.

batch_size=128

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=os.cpu_count())
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=os.cpu_count())
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=os.cpu_count())

# %%
next(iter(train_dataloader))
# Out:
# [tensor([[10., 37., 46.,  ..., 56., 56., 56.],
#          [13., 43., 47.,  ..., 56., 56., 56.],
#          [ 9., 49., 54.,  ..., 56., 56., 56.],
#          ...,
#          [28., 29., 53.,  ..., 56., 56., 56.],
#          [ 6., 49.,  0.,  ..., 56., 56., 56.],
#          [ 9., 49., 42.,  ..., 56., 56., 56.]]),
#  tensor([1, 3, 2, 1, 3, 3, 3, 3, 4, 3, 3, 3, 1, 3, 3, 1, 1, 1, 2, 3, 1, 1, 1, 1,
#          3, 2, 3, 3, 0, 1, 1, 3, 3, 4, 1, 3, 3, 1, 3, 2, 1, 1, 2, 2, 0, 3, 3, 3,
#          3, 3, 3, 3, 4, 1, 3, 3, 0, 2, 3, 1, 2, 1, 4, 1, 2, 3, 1, 0, 3, 3, 3, 3,
#          1, 2, 3, 0, 1, 3, 3, 3, 3, 1, 3, 1, 3, 3, 1, 3, 3, 3, 2, 1, 1, 3, 2, 3,
#          1, 1, 3, 0, 1, 1, 1, 2, 1, 2, 0, 3, 1, 1, 1, 3, 3, 3, 3, 1, 4, 3, 3, 1,
#          3, 1, 3, 3, 1, 1, 3, 3])]

# %%
for i_batch, sample_batched in enumerate(train_dataloader):
    print(i_batch, sample_batched[0].size(), sample_batched[1].size())
    if i_batch == 2:
        break
# Out:
# 0 torch.Size([128, 30]) torch.Size([128])
# 1 torch.Size([128, 30]) torch.Size([128])
# 2 torch.Size([128, 30]) torch.Size([128])

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the Transformer model
class Transformer(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, nhead, num_layers=1):
        super(Transformer, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.pos_encoder = PositionalEncoding(hidden_size)
        encoder_layers = nn.TransformerEncoderLayer(hidden_size, nhead, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.fc = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input):
        embedded = self.embedding(input.type(torch.IntTensor).to(input.device))
        pos_encoded = self.pos_encoder(embedded)
        out = self.transformer_encoder(pos_encoded) # (batch, seq, feature)
        out = out[:, -1, :] # drop seq
        out = self.fc(out)
        out = self.softmax(out) # (batch, out_cats)
        return out

n_hidden = 256 # 128
seq_len = seq_len
vocab_size = n_letters + 1 + 1 # vocab + oob + 1

model = Transformer(vocab_size, n_hidden, n_categories, nhead=4, num_layers=2)
model.to(device)
# Out:
# Transformer(
#   (embedding): Embedding(57, 256)
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (linear1): Linear(in_features=256, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=256, bias=True)
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (fc): Linear(in_features=256, out_features=5, bias=True)
#   (softmax): LogSoftmax(dim=1)
# )

# %%
input = lineToTensor('Rogers Renee')

print("input shape : ",input.shape)
print("input shape w batch : ", input.unsqueeze(0).shape)
#print(hidden.shape)

# sending with batch 1
output = model(input.unsqueeze(0).to(device))
# print(output) - has 47x8 log values
print(output.shape)
print(output)
print(torch.argmax(output))
print(f"model predicted w/o train - {all_categories[torch.argmax(output).item()]}")
# Out:
# input shape :  torch.Size([30])
# input shape w batch :  torch.Size([1, 30])
# torch.Size([1, 5])
# tensor([[-1.7602, -1.9035, -2.4558, -0.9444, -1.5886]], device='cuda:0',
#        grad_fn=<LogSoftmaxBackward0>)
# tensor(3, device='cuda:0')
# model predicted w/o train - nh_white

# %% [markdown]
# ## Training

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
epochs = 100
lr = 0.0005 # 0.005 is very slow


# CrossEntropyLoss expects raw prediction values while NLLLoss expects log probabilities.
# criterion = nn.CrossEntropyLoss() # nn.NLLLoss()
# since we are using nn.LogSoftmax as final layer at model
criterion = nn.NLLLoss()

#optimizer = AdamW(model.parameters(), lr)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30, eta_min=1e-5)

early_stopper = EarlyStopper(patience=10)

mb = master_bar(range(epochs))
mb.names = ['Training loss', 'Validation loss']

x = []
training_losses = []
validation_losses = []

valid_mean_min = np.Inf

till_batch = 100

for epoch in mb:
  x.append(epoch)
  # Train
  i = 0
  model.train()
  total_loss = torch.Tensor([0.0]).to(device)
  for batch in progress_bar(train_dataloader, parent=mb):
    model.zero_grad()
    input = batch[0].to(device)
    label = batch[1].to(device)
    output = model(input)
    loss = criterion(output, label)
    # backward propagation
    loss.backward()
    optimizer.step()
    with torch.no_grad():
      total_loss += loss.item()
    i += 1
    #if i == till_batch:
    #  break

  # decay lr
  scheduler.step()

  mean = total_loss / len(train_dataloader)
  #mean = total_loss / till_batch
  training_losses.append(mean.cpu())

  # Evaluate
  i = 0
  model.eval()
  validation_loss = torch.Tensor([0.0]).to(device)
  with torch.no_grad():
    for batch in progress_bar(val_dataloader, parent=mb):
      input = batch[0].to(device)
      label = batch[1].to(device)
      output = model(input)
      loss = criterion(output, label)
      validation_loss += loss.item()
      i += 1
      #if i == till_batch:
      #  break

  val_mean = validation_loss / len(val_dataloader)
  #val_mean = validation_loss / till_batch

  validation_losses.append(val_mean.cpu())
  # Update training chart
  mb.update_graph([[x, training_losses], [x, validation_losses]], [0,epochs])
  mb.write(f"\nEpoch {epoch}: Training loss {mean.item():.6f} validation loss {val_mean.item():.6f} with lr {lr:.6f}")
  # save model if validation loss has decreased
  if val_mean.item() <= valid_mean_min:
      print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
      valid_mean_min,
      val_mean.item()))
      torch.save(model.state_dict(), '/content/drive/MyDrive/Colab/ethnicolor/transformer_lastname.pt')
      valid_mean_min = val_mean.item()

  if early_stopper.early_stop(val_mean.item()):
        break
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 0: Training loss 0.972470 validation loss 0.911322 with lr 0.000500<p>
# Epoch 1: Training loss 0.915568 validation loss 0.888493 with lr 0.000500<p>
# Epoch 2: Training loss 0.895168 validation loss 0.866666 with lr 0.000500<p>
# Epoch 3: Training loss 0.872330 validation loss 0.841949 with lr 0.000500<p>
# Epoch 4: Training loss 0.854262 validation loss 0.829526 with lr 0.000500<p>
# Epoch 5: Training loss 0.843302 validation loss 0.821801 with lr 0.000500<p>
# Epoch 6: Training loss 0.834950 validation loss 0.812855 with lr 0.000500<p>
# Epoch 7: Training loss 0.828024 validation loss 0.808916 with lr 0.000500<p>
# Epoch 8: Training loss 0.823799 validation loss 0.805657 with lr 0.000500<p>
# Epoch 9: Training loss 0.819669 validation loss 0.802810 with lr 0.000500<p>
# Epoch 10: Training loss 0.817051 validation loss 0.801424 with lr 0.000500<p>
# Epoch 11: Training loss 0.814956 validation loss 0.798371 with lr 0.000500<p>
# Epoch 12: Training loss 0.813273 validation loss 0.799631 with lr 0.000500<p>
# Epoch 13: Training loss 0.811256 validation loss 0.796599 with lr 0.000500<p>
# Epoch 14: Training loss 0.809805 validation loss 0.795919 with lr 0.000500<p>
# Epoch 15: Training loss 0.808765 validation loss 0.795227 with lr 0.000500<p>
# Epoch 16: Training loss 0.808330 validation loss 0.794181 with lr 0.000500<p>
# Epoch 17: Training loss 0.806994 validation loss 0.795025 with lr 0.000500<p>
# Epoch 18: Training loss 0.806395 validation loss 0.793764 with lr 0.000500<p>
# Epoch 19: Training loss 0.805544 validation loss 0.793158 with lr 0.000500<p>
# Epoch 20: Training loss 0.805383 validation loss 0.792545 with lr 0.000500<p>
# Epoch 21: Training loss 0.804947 validation loss 0.792656 with lr 0.000500<p>
# Epoch 22: Training loss 0.804385 validation loss 0.792179 with lr 0.000500<p>
# Epoch 23: Training loss 0.804427 validation loss 0.792198 with lr 0.000500<p>
# Epoch 24: Training loss 0.804183 validation loss 0.792826 with lr 0.000500<p>
# Epoch 25: Training loss 0.804154 validation loss 0.791984 with lr 0.000500<p>
# Epoch 26: Training loss 0.804150 validation loss 0.791692 with lr 0.000500<p>
# Epoch 27: Training loss 0.804115 validation loss 0.791665 with lr 0.000500<p>
# Epoch 28: Training loss 0.803623 validation loss 0.791838 with lr 0.000500<p>
# Epoch 29: Training loss 0.803948 validation loss 0.792142 with lr 0.000500<p>
# Epoch 30: Training loss 0.804133 validation loss 0.791528 with lr 0.000500<p>
# Epoch 31: Training loss 0.803645 validation loss 0.791660 with lr 0.000500<p>
# Epoch 32: Training loss 0.803960 validation loss 0.791802 with lr 0.000500<p>
# Epoch 33: Training loss 0.803761 validation loss 0.791895 with lr 0.000500<p>
# Epoch 34: Training loss 0.803798 validation loss 0.791241 with lr 0.000500<p>
# Epoch 35: Training loss 0.803509 validation loss 0.791275 with lr 0.000500<p>
# Epoch 36: Training loss 0.803665 validation loss 0.790943 with lr 0.000500<p>
# Epoch 37: Training loss 0.803412 validation loss 0.791265 with lr 0.000500<p>
# Epoch 38: Training loss 0.803196 validation loss 0.791112 with lr 0.000500<p>
# Epoch 39: Training loss 0.802799 validation loss 0.791207 with lr 0.000500<p>
# Epoch 40: Training loss 0.802705 validation loss 0.790584 with lr 0.000500<p>
# Epoch 41: Training loss 0.802259 validation loss 0.790191 with lr 0.000500<p>
# Epoch 42: Training loss 0.801756 validation loss 0.790041 with lr 0.000500<p>
# Epoch 43: Training loss 0.801449 validation loss 0.789915 with lr 0.000500<p>
# Epoch 44: Training loss 0.801043 validation loss 0.788661 with lr 0.000500<p>
# Epoch 45: Training loss 0.800379 validation loss 0.788286 with lr 0.000500<p>
# Epoch 46: Training loss 0.799999 validation loss 0.788367 with lr 0.000500<p>
# Epoch 47: Training loss 0.799388 validation loss 0.788814 with lr 0.000500<p>
# Epoch 48: Training loss 0.799000 validation loss 0.787275 with lr 0.000500<p>
# Epoch 49: Training loss 0.798471 validation loss 0.786696 with lr 0.000500<p>
# Epoch 50: Training loss 0.797666 validation loss 0.786980 with lr 0.000500<p>
# Epoch 51: Training loss 0.797208 validation loss 0.785429 with lr 0.000500<p>
# Epoch 52: Training loss 0.796282 validation loss 0.785050 with lr 0.000500<p>
# Epoch 53: Training loss 0.795368 validation loss 0.785245 with lr 0.000500<p>
# Epoch 54: Training loss 0.794924 validation loss 0.785039 with lr 0.000500<p>
# Epoch 55: Training loss 0.794137 validation loss 0.784433 with lr 0.000500<p>
# Epoch 56: Training loss 0.793751 validation loss 0.782589 with lr 0.000500<p>
# Epoch 57: Training loss 0.793303 validation loss 0.783357 with lr 0.000500<p>
# Epoch 58: Training loss 0.792360 validation loss 0.781823 with lr 0.000500<p>
# Epoch 59: Training loss 0.792088 validation loss 0.780293 with lr 0.000500<p>
# Epoch 60: Training loss 0.791235 validation loss 0.782502 with lr 0.000500<p>
# Epoch 61: Training loss 0.790647 validation loss 0.780508 with lr 0.000500<p>
# Epoch 62: Training loss 0.790433 validation loss 0.779639 with lr 0.000500<p>
# Epoch 63: Training loss 0.789731 validation loss 0.779744 with lr 0.000500<p>
# Epoch 64: Training loss 0.789132 validation loss 0.778712 with lr 0.000500<p>
# Epoch 65: Training loss 0.788726 validation loss 0.779982 with lr 0.000500<p>
# Epoch 66: Training loss 0.788330 validation loss 0.777589 with lr 0.000500<p>
# Epoch 67: Training loss 0.788081 validation loss 0.777171 with lr 0.000500<p>
# Epoch 68: Training loss 0.787282 validation loss 0.777606 with lr 0.000500<p>
# Epoch 69: Training loss 0.787113 validation loss 0.776812 with lr 0.000500<p>
# Epoch 70: Training loss 0.786447 validation loss 0.777026 with lr 0.000500<p>
# Epoch 71: Training loss 0.786361 validation loss 0.776379 with lr 0.000500<p>
# Epoch 72: Training loss 0.785965 validation loss 0.775424 with lr 0.000500<p>
# Epoch 73: Training loss 0.785768 validation loss 0.775655 with lr 0.000500<p>
# Epoch 74: Training loss 0.785338 validation loss 0.775396 with lr 0.000500<p>
# Epoch 75: Training loss 0.785348 validation loss 0.774754 with lr 0.000500<p>
# Epoch 76: Training loss 0.784870 validation loss 0.774651 with lr 0.000500<p>
# Epoch 77: Training loss 0.784814 validation loss 0.775531 with lr 0.000500<p>
# Epoch 78: Training loss 0.784791 validation loss 0.775029 with lr 0.000500<p>
# Epoch 79: Training loss 0.784385 validation loss 0.775875 with lr 0.000500<p>
# Epoch 80: Training loss 0.784187 validation loss 0.775855 with lr 0.000500<p>
# Epoch 81: Training loss 0.784446 validation loss 0.775094 with lr 0.000500<p>
# Epoch 82: Training loss 0.784099 validation loss 0.774851 with lr 0.000500<p>
# Epoch 83: Training loss 0.784167 validation loss 0.774891 with lr 0.000500<p>
# Epoch 84: Training loss 0.784137 validation loss 0.774757 with lr 0.000500<p>
# Epoch 85: Training loss 0.784538 validation loss 0.774530 with lr 0.000500<p>
# Epoch 86: Training loss 0.784087 validation loss 0.774349 with lr 0.000500<p>
# Epoch 87: Training loss 0.783850 validation loss 0.774546 with lr 0.000500<p>
# Epoch 88: Training loss 0.783920 validation loss 0.774921 with lr 0.000500<p>
# Epoch 89: Training loss 0.783996 validation loss 0.774365 with lr 0.000500<p>
# Epoch 90: Training loss 0.783885 validation loss 0.774594 with lr 0.000500<p>
# Epoch 91: Training loss 0.784014 validation loss 0.774499 with lr 0.000500<p>
# Epoch 92: Training loss 0.783798 validation loss 0.774811 with lr 0.000500<p>
# Epoch 93: Training loss 0.783983 validation loss 0.774592 with lr 0.000500<p>
# Epoch 94: Training loss 0.784164 validation loss 0.774804 with lr 0.000500<p>
# Epoch 95: Training loss 0.784054 validation loss 0.774872 with lr 0.000500<p>
# Epoch 96: Training loss 0.783752 validation loss 0.774308 with lr 0.000500<p>
# Epoch 97: Training loss 0.783994 validation loss 0.774413 with lr 0.000500<p>
# Epoch 98: Training loss 0.783707 validation loss 0.774745 with lr 0.000500<p>
# Epoch 99: Training loss 0.783485 validation loss 0.774636 with lr 0.000500
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   ary = asanyarray(ary)
# Validation loss decreased (inf --> 0.911322).  Saving model ...
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# Validation loss decreased (0.911322 --> 0.888493).  Saving model ...
# Validation loss decreased (0.888493 --> 0.866666).  Saving model ...
# Validation loss decreased (0.866666 --> 0.841949).  Saving model ...
# Validation loss decreased (0.841949 --> 0.829526).  Saving model ...
# Validation loss decreased (0.829526 --> 0.821801).  Saving model ...
# Validation loss decreased (0.821801 --> 0.812855).  Saving model ...
# Validation loss decreased (0.812855 --> 0.808916).  Saving model ...
# Validation loss decreased (0.808916 --> 0.805657).  Saving model ...
# Validation loss decreased (0.805657 --> 0.802810).  Saving model ...
# Validation loss decreased (0.802810 --> 0.801424).  Saving model ...
# Validation loss decreased (0.801424 --> 0.798371).  Saving model ...
# Validation loss decreased (0.798371 --> 0.796599).  Saving model ...
# Validation loss decreased (0.796599 --> 0.795919).  Saving model ...
# Validation loss decreased (0.795919 --> 0.795227).  Saving model ...
# Validation loss decreased (0.795227 --> 0.794181).  Saving model ...
# Validation loss decreased (0.794181 --> 0.793764).  Saving model ...
# Validation loss decreased (0.793764 --> 0.793158).  Saving model ...
# Validation loss decreased (0.793158 --> 0.792545).  Saving model ...
# Validation loss decreased (0.792545 --> 0.792179).  Saving model ...
# Validation loss decreased (0.792179 --> 0.791984).  Saving model ...
# Validation loss decreased (0.791984 --> 0.791692).  Saving model ...
# Validation loss decreased (0.791692 --> 0.791665).  Saving model ...
# Validation loss decreased (0.791665 --> 0.791528).  Saving model ...
# Validation loss decreased (0.791528 --> 0.791241).  Saving model ...
# Validation loss decreased (0.791241 --> 0.790943).  Saving model ...
# Validation loss decreased (0.790943 --> 0.790584).  Saving model ...
# Validation loss decreased (0.790584 --> 0.790191).  Saving model ...
# Validation loss decreased (0.790191 --> 0.790041).  Saving model ...
# Validation loss decreased (0.790041 --> 0.789915).  Saving model ...
# Validation loss decreased (0.789915 --> 0.788661).  Saving model ...
# Validation loss decreased (0.788661 --> 0.788286).  Saving model ...
# Validation loss decreased (0.788286 --> 0.787275).  Saving model ...
# Validation loss decreased (0.787275 --> 0.786696).  Saving model ...
# Validation loss decreased (0.786696 --> 0.785429).  Saving model ...
# Validation loss decreased (0.785429 --> 0.785050).  Saving model ...
# Validation loss decreased (0.785050 --> 0.785039).  Saving model ...
# Validation loss decreased (0.785039 --> 0.784433).  Saving model ...
# Validation loss decreased (0.784433 --> 0.782589).  Saving model ...
# Validation loss decreased (0.782589 --> 0.781823).  Saving model ...
# Validation loss decreased (0.781823 --> 0.780293).  Saving model ...
# Validation loss decreased (0.780293 --> 0.779639).  Saving model ...
# Validation loss decreased (0.779639 --> 0.778712).  Saving model ...
# Validation loss decreased (0.778712 --> 0.777589).  Saving model ...
# Validation loss decreased (0.777589 --> 0.777171).  Saving model ...
# Validation loss decreased (0.777171 --> 0.776812).  Saving model ...
# Validation loss decreased (0.776812 --> 0.776379).  Saving model ...
# Validation loss decreased (0.776379 --> 0.775424).  Saving model ...
# Validation loss decreased (0.775424 --> 0.775396).  Saving model ...
# Validation loss decreased (0.775396 --> 0.774754).  Saving model ...
# Validation loss decreased (0.774754 --> 0.774651).  Saving model ...
# Validation loss decreased (0.774651 --> 0.774530).  Saving model ...
# Validation loss decreased (0.774530 --> 0.774349).  Saving model ...
# Validation loss decreased (0.774349 --> 0.774308).  Saving model ...

# %% [markdown]
# ## Save Model

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/Colab/ethnicolor/transformer_lastname_after_train.pt')

# %%
model.load_state_dict(torch.load('/content/drive/MyDrive/Colab/ethnicolor/transformer_fullname_after_train.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Testing

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# track test loss
test_loss = 0.0


class_correct = list(0. for i in range(n_categories))
class_total = list(0. for i in range(n_categories))


actual = []
predictions = []

model.eval()
# iterate over test data
pbar = tqdm(test_dataloader, total=len(test_dataloader), position=0, desc="Testing", leave=True)
for batch in pbar:
    # move tensors to GPU if CUDA is available
    input = batch[0].to(device)
    label = batch[1].to(device)
    output = model(input)
    loss = criterion(output, label)
    test_loss += loss.item()
    pred = torch.argmax(output, dim=1)
    correct_tensor = pred.eq(label.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(label.shape[0]):
        l = label.data[i]
        class_correct[l.long()] += correct[i].item()
        class_total[l.long()] += 1
        # for confusion matrix
        actual.append(all_categories[label.data[i].item()])
        predictions.append(all_categories[pred.data[i].item()])


# plot confusion matrix
cm = confusion_matrix(actual, predictions, labels=all_categories)
print(classification_report(actual, predictions))
# Out:
# Testing: 100%|██████████| 825/825 [00:14<00:00, 55.27it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        asian       0.38      0.03      0.06      3646
#     hispanic       0.80      0.80      0.80     32431
#     nh_black       0.48      0.09      0.16     10398
#     nh_white       0.72      0.91      0.80     56236
#        other       0.00      0.00      0.00      2889
#
#     accuracy                           0.74    105600
#    macro avg       0.48      0.37      0.36    105600
# weighted avg       0.69      0.74      0.69    105600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

cmp = ConfusionMatrixDisplay(cm, display_labels=all_categories)
fig, ax = plt.subplots(figsize=(8,8))
cmp.plot(ax=ax, xticks_rotation='vertical')

# %%
# average test loss
test_loss = test_loss/len(test_dataloader)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(len(all_categories)):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            all_categories[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (all_categories[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.777511
#
# Test Accuracy of asian:  3% (127/3646)
# Test Accuracy of hispanic: 79% (25849/32431)
# Test Accuracy of nh_black:  9% (984/10398)
# Test Accuracy of nh_white: 90% (51052/56236)
# Test Accuracy of other:  0% ( 0/2889)
#
# Test Accuracy (Overall): 73% (78012/105600)

# %%
name = "Ward Stephanie"
name_tokens = lineToTensor(name)
inp = name_tokens
print(inp.shape)
out = model(inp.unsqueeze(0).to(device))
print(out.shape)
out = torch.argmax(out)
print(out)
print(all_categories[out.item()])
# Out:
# torch.Size([30])
# torch.Size([1, 5])
# tensor(3, device='cuda:0')
# nh_white
